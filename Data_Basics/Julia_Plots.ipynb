# %%
#Shishir Khanal
#26/11/2022
#Hello World in Julia

# %%
using Pkg

# %%
Pkg.add("Plots");
#Pkg.add("Pyplots");
Pkg.add("GR");
Pkg.add("UnicodePlots");
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.8/Project.toml`
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [28b8d3ca] + GR v0.71.1
#   No Changes to `~/.julia/environments/v1.8/Manifest.toml`
#    Resolving package versions...
#    Installed MarchingCubes ──── v0.1.4
#    Installed StaticArraysCore ─ v1.4.0
#    Installed Unitful ────────── v1.12.1
#    Installed ConstructionBase ─ v1.4.1
#    Installed FreeType ───────── v4.0.0
#    Installed StaticArrays ───── v1.5.10
#    Installed FileIO ─────────── v1.16.0
#    Installed UnicodePlots ───── v3.3.0
#    Installed CEnum ──────────── v0.4.2
#     Updating `~/.julia/environments/v1.8/Project.toml`
#   [b8865327] + UnicodePlots v3.3.0
#     Updating `~/.julia/environments/v1.8/Manifest.toml`
#   [fa961155] + CEnum v0.4.2
#   [187b0558] + ConstructionBase v1.4.1
#   [5789e2e9] + FileIO v1.16.0
#   [b38be410] + FreeType v4.0.0
#   [299715c1] + MarchingCubes v0.1.4
#   [90137ffa] + StaticArrays v1.5.10
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [b8865327] + UnicodePlots v3.3.0
#   [1986cc42] + Unitful v1.12.1
# Precompiling project...
#   ✓ CEnum
#   ✓ ConstructionBase
#   ✓ FileIO
#   ✓ StaticArraysCore
#   ✓ FreeType
#   ✓ StaticArrays
#   ✓ MarchingCubes
#   ✓ Unitful
#   ✓ UnicodePlots
#   9 dependencies successfully precompiled in 83 seconds. 159 already precompiled.

# %%
using Plots
using UnicodePlots

# %%
#gr()
unicodeplots()
# Out:
# Plots.UnicodePlotsBackend()

# %%
year = [x for x in range(2000, length= 10)]
# Out:
# 10-element Vector{Int64}:
#  2000
#  2001
#  2002
#  2003
#  2004
#  2005
#  2006
#  2007
#  2008
#  2009

# %%
sale = 100 * rand(10)
# Out:
# 10-element Vector{Float64}:
#  67.17230720472232
#  14.817235580936828
#  81.84141913328898
#  50.026613731522254
#  19.7307959418337
#  81.33828062427656
#  41.75362324854459
#  29.08652915150275
#  78.81645004522329
#  14.738215796142251

# %%
plot(year, sale, label="Line Plot")
# Out:
#            +----------------------------------------+
#    83.8545 |         ,           .,                 | Line Plot
#            |         |.          |.           ]     |
#            |        | ,          |",         .",    |
#            | ,      /  \         | .         . \    |
#            | |      ,  ",       |  ",        , ,    |
#            | |.    ,`   .       |   .       ,` ",   |
#            |  .    .     .      |   ",      |   .   |
#            |  .    .     |.    |     .     .`   .   |
#            |  ",   |      .    |     ",    .    |.  |
#            |   \  |        .   |      '.   ,     .  |
#            |   ,  |        |. |         *.,`     .  |
#            |    | |         . |          '/      |  |
#            |    .,`         ".,                   | |
#            |    |/           \`                   | |
#    12.7251 |     /                                | |
#            +----------------------------------------+
#             1999.73                          2009.27

# %%
scatter!(year, sale, labels="Scatter Plot")
xlabel!("Year")
ylabel!("Sale")
title!("Sale between 2000 and 2009")
# Out:
#                    Sale between 2000 and 2009
#            +----------------------------------------+
#    83.8545 |         ⚬           .⚬                 | Line Plot
#            |         |.          |.           ⚬     | Scatter Plot
#            |        | ,          |",         .",    |
#            | ⚬      /  \         | .         . \    |
#            | |      ,  ",       |  ",        , ,    |
#            | |.    ,`   .       |   .       ,` ",   |
#            |  .    .     .      |   ",      |   .   |
#       Sale |  .    .     ⚬.    |     .     .`   .   |
#            |  ",   |      .    |     "⚬    .    |.  |
#            |   \  |        .   |      '.   ,     .  |
#            |   ,  |        |. |         *.,`     .  |
#            |    | |         . |          '⚬      |  |
#            |    .,`         ".,                   | |
#            |    |/           ⚬`                   | |
#    12.7251 |     ⚬                                ⚬ |
#            +----------------------------------------+
#             1999.73          Year            2009.27

# %%
x = -5:0.2:5
y = x.^2
plot(x, y)
# Out:
#          +----------------------------------------+
#    25.75 | .                  |                 . | y1
#          | \.                 |                ./ |
#          |  .                 |                .  |
#          |   \                |               /   |
#          |   ".               |              .`   |
#          |    |.              |             ./    |
#          |     .              |            ./     |
#          |      \.            |            .      |
#          |       \            |          ./       |
#          |        *.          |         ./        |
#          |         \.         |        ./         |
#          |          ".        |       r'          |
#          |            \.      |     ./            |
#          |             "*..   |   ./`             |
#    -0.75 |--------------------r-------------------|
#          +----------------------------------------+
#           -5.3                                 5.3

# %%
p1 = plot(x, x)
p2 = plot(y, x)
p3 = plot(sin, x)
p4 = plot(cos, x)
plot(p1, p2, p3, p4, layout=(1,4))
# Out:
#         +----------------------------------------+            +----------------------------------------+                +----------------------------------------+                +----------------------------------------+
#     5.3 |                    |                .r | y1     5.3 | |                               ___r-* | y1     1.05955 | r-.                |   .--.            | y1     1.05995 |                  .-r.                  | y1
#         |                    |             ../`  |            | |                      __.---"""       |                |   "\               |  .`  \.           |                |                 ./ |".                 |
#         |                    |           _*'     |            | |              ._.--/""                |                |    ".              | ,`    \.          |                |                ,`  | ",                |
#         |                    |        .r"        |            | |        ._r-""'                       |                |     \.             | ,      \          |                |                /   |  ,                |
#         |                    |     ../`          |            | |   ._r*"`                             |                |      \             |.        .         |                |               .    |  ".               |
#         |                    |   _*'             |            | |..*'                                  |                |      |.            |`        ,         |                | ,            .`    |   |.            . |
#         |                    |.r/                |            | v/                                     |                |       .            /          .        |                | ,            .     |    \            , |
#         |-------------------rr-------------------|            |-r--------------------------------------|                |--------r-----------r-----------r-------|                |--v-----------------r-----r----------v--|
#         |                .-' |                   |            | ^,                                     |                |        ,          .|           \       |                |  \.         /      |     \          ,  |
#         |             .-/    |                   |            | |"\._                                  |                |         .        ,`|           ",      |                |   \        .`      |     |.        .   |
#         |          .r/`      |                   |            | |    "*._.                             |                |         \.       . |            .      |                |   ,.       .       |      .       .`   |
#         |        _-'         |                   |            | |        ""--._.                       |                |          \      .  |             .     |                |    .      ,`       |      ",      /    |
#         |     .-/            |                   |            | |              '""--._.                |                |          ".    ,`  |             \.    |                |    ".    ./        |       \.    .`    |
#         |  ../`              |                   |            | |                     """"---___       |                |           ".  ./   |              ,.   |                |     \.  ./         |        \.  .'     |
#    -5.3 | *'                 |                   |       -5.3 | |                               """*-- |       -1.05955 |            "--'    |               \-* |       -1.05824 |      "--/          |         '--`      |
#         +----------------------------------------+            +----------------------------------------+                +----------------------------------------+                +----------------------------------------+
#          -5.3                                 5.3              -0.75                              25.75                  -5.3                                 5.3                  -5.3                                 5.3

# %%
plot(sin, x)
plot!(cos, x)
# Out:
#             +----------------------------------------+
#     1.05999 | r-.              .-r.  .--.            | y1
#             |   ".            ./ |"..`  \.           | y2
#             |    ".          ,`  | ||    \.          |
#             |     \.         /   | ,,     \          |
#             |      \        .    |. ".     .         |
#             | ,    |.      .`    |`  |.    ,       . |
#             | ,     .      .     /    \     .      , |
#             |--v-----r-----------r-----r-----r----v--|
#             |  \.    ,    /     .|     \     \    ,  |
#             |   \     .  .`    ,`|     |.    ",  .   |
#             |   ,.    \. ,     . |      .     . .`   |
#             |    .     \.     .  |      ".     ./    |
#             |    ".    .(    ,`  |       ",    ).    |
#             |     \.  ./".  ./   |        \.  .',.   |
#    -1.05956 |      "--/  "--'    |         '--`  \-* |
#             +----------------------------------------+
#              -5.3                                 5.3

# %%
#histogram(rand(100000))
histogram(randn(1000))
# Out:
#           +----------------------------------------+
#    190.55 |                  |-⚬,                  | y1
#           |                /⚬|  L⚬.                | y1
#           |                | |  | |                |
#           |              |⚬\ |  | |                |
#           |              | | |  | |                |
#           |              | | |  | |                |
#           |           ,⚬-| | |  | |                |
#           |           |  | | |  | /⚬|              |
#           |           |  | | |  | | |              |
#           |           |  | | |  | | |              |
#           |         r⚬-  | | |  | | |              |
#           |         | |  | | |  | | |              |
#           |         | |  | | |  | | |"⚬|           |
#           |      ._⚬| |  | | |  | | |  r⚬-         |
#     -5.55 |---⚬-⚬-------------------------⚬--⚬-⚬---|
#           +----------------------------------------+
#            -3.9635                           4.4635

# %%
histogram2d(randn(10000), randn(10000))
# Out:
#       +----------------------------------------+
#     5 |                                        |
#       |                                        |
#       |                                        |
#       |                                        |
#       |                                        |
#       |                ░░░░░░░░░               |
#       |            ░░░░▒▒▒▒▒▒▒░░░░░░           |
#       |          ░░░▒▒▒▓▓▓█▓▓▓▒▒▒▒░░░          |
#       |          ░░░▒▒▓▓▓████▓▓▓▒▒░░           |
#       |          ░ ░░▒▒▓▓▓▓▓▓▓▒▒▒░░░░          |
#       |            ░░░░░▒▒░▒▒░░░░░ ░           |
#       |               ░░░ ░░░░  ░              |
#       |                                        |
#       |                                        |
#    -4 |                                        |
#       +----------------------------------------+
#        -4                                     4

# %%
bar([1,2,3])
# Out:
#          +----------------------------------------+
#     3.09 |                           ,----⚬-----  | y1
#          |                           |         |  | y1
#          |                           |         |  |
#          |                           |         |  |
#          |                           |         |  |
#          |              |"""""⚬""""| |         |  |
#          |              |          | |         |  |
#          |              |          | |         |  |
#          |              |          | |         |  |
#          |  _____⚬____. |          | |         |  |
#          |  |         | |          | |         |  |
#          |  |         | |          | |         |  |
#          |  |         | |          | |         |  |
#          |  |         | |          | |         |  |
#    -0.09 |----------------------------------------|
#          +----------------------------------------+
#           0.42696                          3.57304

# %%
bar(randn(10))
# Out:
#              +----------------------------------------+
#      1.00337 ||                   ,⚬-,                | y1
#              ||    ._⚬_           |  |                | y1
#              ||    |  |           |  |                |
#              ||    |  |    r⚬-,   |  |                |
#              ||    |  |    |  |   |  |                |
#              ||    |  |    |  |   |  |                |
#              ||    |  |    |  |"⚬\|  |                |
#              |L____________L__L__11__L________________|
#              || |  |   |  |          |-⚬-|  ||  |  |  |
#              || |  |   |  |              |  ||  |  |  |
#              || L⚬_|   |  |              |  |"⚬"|  |  |
#              ||        |  |              |  |   |  |  |
#              ||        |  |              |  |   ""⚬"  |
#              ||        |  |              |  |         |
#    -0.927903 ||        '⚬"'              \-⚬/         |
#              +----------------------------------------+
#               -0.00564                         11.0056

# %%
pie(rand(5))
# Out:
#             +----------------------------------------+
#        1.06 |            .__----------__.            | 1
#             |        _r*"'\.    |       '"-..        | 2
#             |     .r"      \.   |           "\..     | 3
#             |   .*'         \.  |              "\.   | 4
#             |  .'            \. |                \.  | 5
#             | .`              \.|                 ", |
#             | ,                \|       .____.-----\ |
#             |-r-----------------{--------------------|
#             | \                 |                  . |
#             | |.               .]                 ,/ |
#             |  '.             ./|                ./  |
#             |   "\.           /.|              .r`   |
#             |     '*_        ,`||            _-`     |
#             |        "*-_.   . ||       ._r*"        |
#    -1.05991 |            """----------""'            |
#             +----------------------------------------+
#              -1.05995                            1.06
